# %%
'''
- what are DS?

> a storage that is used to store and organize data
> way of arranging data so that it can be accessed and updated 
efficiently


> important thing is that i have to select right DS acording to 
my requriement and project
'''

# *** DS is storaging data efficiently
# Out:
# '\n- what are DS?\n\n> a storage that is used to store and organize data\n> way of arranging data so that it can be accessed and updated \nefficiently\n\n\n> important thing is that i have to select right DS acording to \nmy requriement and project\n'

# %%
'''
- Types of DS

> it could be divided into two categories:
    - Linear DS
    - Non-Linear DS
    
  * Linear DS
      > 1. the elements are arranged in sequence one after the other
      > 2. elements are arranged in particular order
      
      <Popular linear DS>
  
      1. Array; 1. element in memory are arranged in continuous memory
                2. All the elements of an array are of the same type
            
                ex) [1, 2, 3, 4, 5]
            
      2. Stack; 1. elements are stored in the LIFO
            
                ex) plates where the last plate kept on the pile will
                be removed first(LIFO)
            
      3. Queue; 1. works in the FIFO 
  
                ex) it just works line a queue of people in the ticket
                counter where first person on the queue will get the 
                ticket first
            
      4. Linked List; 1. elements are connected through a series of nodes
                      2. each node contains the data items and address to
                      next node
                  
    * Non Linear DS
        > 1. elements in Non Linear DS are not in any sequence
        > 2. elements are arranged in a hierarchical manner where 
        one element will be connected to one or more elements
        
        (Non Linear DS are futher divided into Graph and Tree)
        
        <Popular Non Linear DS>
        
        1. Graph; 1. each node is called vertex and each vertex
                  is connected to other vertices through edges
                  
                  there are a variety of Popular Graph based DS
                  
        2.Tree; 1. a collection of vertices and edges
                2. there can only be one edge between two vertices
                
                there are a variety of Popular Graph based DS
                
                
    => Linear DS VS Non - Linear DS
    
    - sequential order/ hierarchical manner
    
    - single layer/ differrnt layers
    
    - if we start from the first element, we can traverse all the elements sequentially in a single pass 
      /it might not be possible to traverse all the elements in a single pass

    - the memory utilization is not efficient/ different structure utilize
      memory in different efficient ways depending on the need
      
    - the time complexity increase with data size/ remains the same
    
                  
'''
# Out:
# '\n- Types of DS\n\n> it could be divided into two categories:\n    - Linear DS\n    - Non-Linear DS\n    \n  * Linear DS\n      > 1. the elements are arranged in sequence one after the other\n      > 2. elements are arranged in particular order\n      \n      <Popular linear DS>\n  \n      1. Array; 1. element in memory are arranged in continuous memory\n                2. All the elements of an array are of the same type\n            \n                ex) [1, 2, 3, 4, 5]\n            \n      2. Stack; 1. elements are stored in the LIFO\n            \n                ex) plates where the last plate kept on the pile will\n                be removed first(LIFO)\n            \n      3. Queue; 1. works in the FIFO \n  \n                ex) it just works line a queue of people in the ticket\n                counter where first person on the queue will get the \n                ticket first\n            \n      4. Linked List; 1. elements are connected through a series of nodes\n         
# ...

# %%
'''
- Divide and Conquer Algorithm

> divide and conquer algorithms is
  a strategy of solving a large problem
  
  1) breaking the problem into smaller sub-problems
  2) solving the sub-problems
  3) combining them to get the desired output
  
- How Divide and Conquer Algorithms Work?

> step by step

  1) Divide: devide the given problem into sub-problmes 
              using recursion
              
  2) Conquer: solve the smaller sub-problems recursively
  
  3) Combine: combine the solutions of the sub-problems
  
ex) merge sort
    
    Divede: divide each subpart recursively into two halves
            untill you get individual elements
            
    Conquer & Combine: combine the individual elements in a 
                       sorted manner 
                       
    
    -Time complexity
    
     > T(n) = aT(n/b) + f(n),
       where, 
       n = size of input
       a = number of subproblems in the recursion
       n/b = size of each subproblem. All subproblems are assumed to have the same size.
       f(n) = cost of the work done outside the recursive call,
              which includes the cost of dividing the problem and 
              cost of merging the solutions
              
       *** T(n) = 2T(n log n) + O(n) ≈ O(n log n)



  
'''
